# %%
import pandas as pd
from sklearn.model_selection import KFold, cross_validate
import yaml
import os
import numpy as np
import json
import joblib

# %%
# загружаем данные из sprint 1: update_data.csv
if os.path.exists('/home/mle-user/mle_projects/mle-project-sprint-1-v001/part2_dvc/data/initial_data.csv'):
    data = pd.read_csv('/home/mle-user/mle_projects/mle-project-sprint-1-v001/part2_dvc/data/initial_data.csv')

# %%
data.head()
# Out:
#    floor  is_apartment  kitchen_area  living_area  rooms  studio  total_area
# 0      9             0         10.53    17.549999      1       0   35.099998  \
# 1      7             0         12.90    21.500000      1       0   43.000000
# 2      9             0         16.80    28.000000      2       0   56.000000
# 3      1             0         22.80    38.000000      3       0   76.000000
# 4      3             0          7.20    12.000000      1       0   24.000000
#
#       price  building_id  build_year  building_type_int   latitude  longitude
# 0   9500000         6220        1965                  6  55.717113  37.781120  \
# 1  13500000        18012        2001                  2  55.794849  37.608013
# 2  13500000        17821        2000                  4  55.740040  37.761742
# 3  20000000        18579        2002                  4  55.672016  37.570877
# 4   5200000         9293        1971                  1  55.808807  37.707306
#
# ...

# %%
# сохраняем данные
os.makedirs('../data', exist_ok=True)
with open('../data/initial_data.csv', 'wb') as fd:
    data.to_csv('../data/initial_data.csv', index=None)

# %%
# загружаем данные из sprint 1: moscow_metro_stations.csv
if os.path.exists('/home/mle-user/mle_projects/mle-project-sprint-1-v001/part2_dvc/data/moscow_metro_stations.csv'):
    data_m = pd.read_csv('/home/mle-user/mle_projects/mle-project-sprint-1-v001/part2_dvc/data/moscow_metro_stations.csv')

# %%
# сохраняем данные moscow_metro_stations.csv
os.makedirs('../data', exist_ok=True)
with open('../data/moscow_metro_stations.csv', 'wb') as fd:
    data_m.to_csv('../data/moscow_metro_stations.csv', index=None)

# %%
# загружаем модель из sprint 1: fitted_model_CBR.pkl
if os.path.exists('/home/mle-user/mle_projects/mle-project-sprint-1-v001/part2_dvc/models/fitted_model_CBR.pkl'):
    with open('/home/mle-user/mle_projects/mle-project-sprint-1-v001/part2_dvc/models/fitted_model_CBR.pkl', 'rb') as fd:
        model = joblib.load(fd)
# Out:
# /home/mle-user/.local/lib/python3.10/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.4.1.post1 when using version 1.4.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/mle-user/.local/lib/python3.10/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator FunctionTransformer from version 1.4.1.post1 when using version 1.4.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ...

# %%
model
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('binary', 'passthrough',
#                                                   ['is_apartment', 'studio',
#                                                    'has_elevator']),
#                                                  ('cat', 'passthrough',
#                                                   ['build_type_floors']),
#                                                  ('num', StandardScaler(),
#                                                   ['floor', 'kitchen_area',
#                                                    'living_area', 'rooms',
#                                                    'total_area', 'build_year',
#                                                    'building_type_int',
#                                                    'ceiling_height',
#                                                    'flats_count',
# ...

# %%
# сохраняем модель
os.makedirs('../models', exist_ok=True) # создание директории, если её ещё нет
with open('../models/base_model.pkl', 'wb') as fd:
    joblib.dump(model, fd)

# %%
df.loc[df.query('kitchen_area.isnull()', engine='python').index, 'kitchen_area'] = df.loc[df.query('kitchen_area.isnull()', engine='python').index, 'total_area']*0.5
df.loc[df.query('living_area.isnull()', engine='python').index, 'living_area'] = df.loc[df.query('living_area.isnull()', engine='python').index, 'total_area']*0.5
df.loc[df.query('living_ratio.isnull()', engine='python').index, 'living_ratio'] = df.loc[df.query('living_ratio.isnull()', engine='python').index, 'living_area']/df.loc[df.query('living_ratio.isnull()', engine='python').index, 'total_area']
df.loc[df.query('kitchen_ratio.isnull()', engine='python').index, 'kitchen_ratio'] = df.loc[df.query('kitchen_ratio.isnull()', engine='python').index, 'kitchen_area']/df.loc[df.query('kitchen_ratio.isnull()', engine='python').index, 'total_area']
